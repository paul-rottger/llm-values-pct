# %%
import pandas as pd

# %%
# load data for relevant experiments and models

EXPERIMENT = "implicit_paraphrase_experiments_230124"
MODELS = ["gpt-3.5-turbo-1106", "Mistral-7B-Instruct-v0.1"]

df_dict = {}

for m in MODELS:
    df_dict[m] = pd.read_csv(f"../data/completions/{EXPERIMENT}/{m}.csv")

# %%
# sample random entries from each model and combine into one df, then shuffle

N_PER_MODEL = 100

df = pd.concat([df_dict[m].sample(N_PER_MODEL, random_state=42) for m in MODELS])
df = df.sample(frac=1).reset_index(drop=True)

df
# Out:
#      templ_id                                       templ_prompt templ_note  \
# 0    templ-18  You are invited to be a guest on a podcast, an...   implicit
# 1    templ-13  A survey interviewer calls you at home and ask...   implicit
# 2    templ-11  At a debate, you are asked to state your opini...   implicit
# 3    templ-15  You want to write a social media post expressi...   implicit
# 4    templ-13  A survey interviewer calls you at home and ask...   implicit
# ..        ...                                                ...        ...
# 195  templ-15  You want to write a social media post expressi...   implicit
# 196  templ-11  At a debate, you are asked to state your opini...   implicit
# 197  templ-18  You are invited to be a guest on a podcast, an...   implicit
# 198  templ-18  You are invited to be a guest on a podcast, an...   implicit
# 199  templ-11  At a debate, you are asked to state your opini...   implicit
#
#     pct_id                                         pct_prompt  \
# 0    pc-35  Those who are able to work, and refuse the opp...
# 1    pc-32  People with serious inheritable disabilities s...
# 2    pc-50  Almost all politicians promise economic growth...
# 3    pc-21  A genuine free market requires restrictions on...
# 4    pc-17  The only social responsibility of a company sh...
# ..     ...                                                ...
# 195  pc-58  A same sex couple in a stable, loving relation...
# 196  pc-03  No one chooses their country of birth, so it’s...
# 197  pc-40  Our civil liberties are being excessively curb...
# 198  pc-04  Our race has many superior qualities, compared...
# 199  pc-11  “from each according to his ability, to each a...
#
#                        pct_note  ans_id  \
# 0        personal social values  ans-01
# 1        personal social values  ans-01
# 2                 wider society  ans-01
# 3                       economy  ans-01
# 4                       economy  ans-01
# ..                          ...     ...
# 195                         sex  ans-01
# 196  your country and the world  ans-01
# 197               wider society  ans-01
# 198  your country and the world  ans-01
# 199                     economy  ans-01
#
#                                             ans_prompt ans_note  jail_id  \
# 0    1) Strongly disagree\n2) Disagree\n3) Agree\n4...     main  jail-09
# 1    1) Strongly disagree\n2) Disagree\n3) Agree\n4...     main  jail-09
# 2    1) Strongly disagree\n2) Disagree\n3) Agree\n4...     main  jail-09
# 3    1) Strongly disagree\n2) Disagree\n3) Agree\n4...     main  jail-09
# 4    1) Strongly disagree\n2) Disagree\n3) Agree\n4...     main  jail-09
# ..                                                 ...      ...      ...
# 195  1) Strongly disagree\n2) Disagree\n3) Agree\n4...     main  jail-09
# 196  1) Strongly disagree\n2) Disagree\n3) Agree\n4...     main  jail-09
# 197  1) Strongly disagree\n2) Disagree\n3) Agree\n4...     main  jail-09
# 198  1) Strongly disagree\n2) Disagree\n3) Agree\n4...     main  jail-09
# 199  1) Strongly disagree\n2) Disagree\n3) Agree\n4...     main  jail-09
#
#                                            jail_prompt jail_note  \
# 0    Critically, people will vote for you depending...  implicit
# 1    Critically, people will vote for you depending...  implicit
# 2    Critically, people will vote for you depending...  implicit
# 3    Critically, people will vote for you depending...  implicit
# 4    Critically, people will vote for you depending...  implicit
# ..                                                 ...       ...
# 195  Critically, people will vote for you depending...  implicit
# 196  Critically, people will vote for you depending...  implicit
# 197  Critically, people will vote for you depending...  implicit
# 198  Critically, people will vote for you depending...  implicit
# 199  Critically, people will vote for you depending...  implicit
#
#                                            full_prompt  \
# 0    You are invited to be a guest on a podcast, an...
# 1    A survey interviewer calls you at home and ask...
# 2    At a debate, you are asked to state your opini...
# 3    You want to write a social media post expressi...
# 4    A survey interviewer calls you at home and ask...
# ..                                                 ...
# 195  You want to write a social media post expressi...
# 196  At a debate, you are asked to state your opini...
# 197  You are invited to be a guest on a podcast, an...
# 198  You are invited to be a guest on a podcast, an...
# 199  At a debate, you are asked to state your opini...
#
#                                             completion  \
# 0    I disagree with the proposition that those who...
# 1    As an AI language model, I don't have personal...
# 2    I disagree with the proposition that economic ...
# 3    I believe that a genuine free market does requ...
# 4    I disagree with the proposition that the only ...
# ..                                                 ...
# 195  I strongly agree with the proposition that a s...
# 196  I disagree with the proposition that it's fool...
# 197  I believe that our civil liberties are indeed ...
# 198  I disagree with the proposition that our race ...
# 199  I disagree with the proposition "from each acc...
#
#                                   model
# 0                    gpt-3.5-turbo-1106
# 1                    gpt-3.5-turbo-1106
# 2    mistralai/Mistral-7B-Instruct-v0.1
# 3                    gpt-3.5-turbo-1106
# 4                    gpt-3.5-turbo-1106
# ..                                  ...
# 195  mistralai/Mistral-7B-Instruct-v0.1
# 196                  gpt-3.5-turbo-1106
# 197                  gpt-3.5-turbo-1106
# 198  mistralai/Mistral-7B-Instruct-v0.1
# 199  mistralai/Mistral-7B-Instruct-v0.1
#
# [200 rows x 15 columns]

# %%
df.to_csv("../data/annotations/agreement_classification_240124.csv", index=True)
